# %% [markdown]
# ## HEATMAP OF WINDOW SIZE VS BLOCK SIZE FOR NORMAL IOU

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Data
window_sizes = [5, 7, 10, 12, 15]
block_sizes = [2, 3, 4, 5]

# HOTA scores
hota_scores = [
    [82.928, 82.384, 82.561, 82.407],
    [82.555, 82.447, 82.626, 82.858],
    [82.581, 82.488, 82.934, 82.696],
    [82.661, 82.461, 82.243, 82.773],  # ERROR replaced with None
    [82.695, 82.658, 82.881, 82.881]
]

# IDF1 scores
idf1_scores = [
    [81.714, 81.658, 81.917, 81.641],
    [81.988, 81.871, 82.169, 82.374],
    [82.05, 81.889, 82.437, 82.128],
    [82.14, 81.764, 81.65, 82.078],  # ERROR replaced with None
    [82.074, 82.122, 82.219, 82.427]
]
# AssA scores (First dataset)
assa_scores = [
    [72.068, 72.21, 72.471, 72.306],
    [72.458, 72.343, 72.59, 73.058],
    [72.542, 72.461, 73.141, 72.696],
    [72.653, 72.31, 71.999, 72. 919],  # "ERROR" represented as None
    [72.717, 72.66, 72.917, 73.129]
]

# Convert None values to np.nan for heatmap compatibility
hota_scores = np.array(hota_scores, dtype=np.float64)
idf1_scores = np.array(idf1_scores, dtype=np.float64)
assa_scores = np.array(assa_scores, dtype=np.float64)

# Create heatmap for HOTA
plt.figure(figsize=(8, 6))
sns.heatmap(hota_scores, annot=True, fmt=".3f", xticklabels=block_sizes,   annot_kws={"fontsize": 15}, yticklabels=window_sizes, cmap="flare")
# plt.title("HOTA Scores Heatmap")
plt.xlabel("Block Size")
plt.ylabel("Window Size")
# plt.show()
plt.savefig("HOTA_heatmap_normal_iou_Sports.png", dpi = 1000,  bbox_inches='tight', pad_inches=0 )

# Create heatmap for IDF1
plt.figure(figsize=(8, 6))
sns.heatmap(idf1_scores, annot=True, fmt=".3f", xticklabels=block_sizes,annot_kws={"fontsize": 15}, yticklabels=window_sizes, cmap="flare")
# plt.title("IDF1 Scores Heatmap")
plt.xlabel("Block Size")
plt.ylabel("Window Size")
# plt.show()
plt.savefig("IDF1_heatmap_normal_iou_Sports.png", dpi = 1000,  bbox_inches='tight', pad_inches=0 )




# Create heatmap for IDF1
plt.figure(figsize=(8, 6))
sns.heatmap(assa_scores, annot=True, fmt=".3f", xticklabels=block_sizes,annot_kws={"fontsize": 15}, yticklabels=window_sizes, cmap="flare")
# plt.title("AssA Scores Heatmap")
plt.xlabel("Block Size")
plt.ylabel("Window Size")
# plt.show()
plt.savefig("AssA_heatmap_normal_iou_Sports.png", dpi = 1000,  bbox_inches='tight', pad_inches=0 )

# %% [markdown]
# ## HEATMAP FOR WINDOW SIZE VS BLOCK SIZE FOR DANCETRACK

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Data
window_sizes = [5, 7, 10, 12, 15]
block_sizes = [2, 3, 4, 5]

# HOTA scores
hota_scores = [
    [56.916, 57.263, 56.949, 57.069],
    [57.081, 57.252, 56.93, 57.527],
    [57.081, 57.027, 56.319, 57.103],
    [57.733, 56.952, 56.968, 57.384],
    [57.087, 57.107, 57.654, 57.259]
]

# IDF1 scores
idf1_scores = [
    [58.024, 58.778, 58.253, 57.988],
    [58.298, 57.9, 57.975, 58.583],
    [58.246, 57.936, 57.457, 58.64],
    [59.321, 57.965, 58.378, 58.606],
    [58.04, 58.438, 60.341, 58.525]
]



assa_scores = np.array([
    [40.982, 41.498, 41.049, 41.449],
    [41.441, 41.459, 41.074, 42.026],
    [41.394, 41.046, 40.316, 41.397],  # "41.0-46" represented as None
    [42.154, 41.018, 41.154, 41.849],
    [41.296, 41.323, 42.309, 41.456]
], dtype = np.float64)
# Convert the data to numpy arrays
hota_scores = np.array(hota_scores, dtype=np.float64)
idf1_scores = np.array(idf1_scores, dtype=np.float64)

# Create heatmap for HOTA
plt.figure(figsize=(10, 6))
sns.heatmap(hota_scores, annot=True, fmt=".3f", xticklabels=block_sizes,annot_kws={"fontsize": 15}, yticklabels=window_sizes, cmap="YlGnBu")
# plt.title("HOTA Scores Heatmap")
plt.xlabel("Block Size")
plt.ylabel("Window Size")
# plt.show()
plt.savefig("HOTA_heatmap_normal_iou_dance.png", dpi = 1000,  bbox_inches='tight', pad_inches=0 )


# Create heatmap for IDF1
plt.figure(figsize=(10, 6))
sns.heatmap(idf1_scores, annot=True, fmt=".3f", xticklabels=block_sizes, annot_kws={"fontsize": 15},  yticklabels=window_sizes, cmap="YlGnBu")
# plt.title("IDF1 Scores Heatmap")
plt.xlabel("Block Size")
plt.ylabel("Window Size")
# plt.show()
plt.savefig("IDF1_heatmap_normal_iou_dance.png", dpi = 1000,  bbox_inches='tight', pad_inches=0 )



# Create heatmap for IDF1
plt.figure(figsize=(10, 6))
sns.heatmap(assa_scores, annot=True, fmt=".3f", xticklabels=block_sizes,  annot_kws={"fontsize": 15},  yticklabels=window_sizes, cmap="YlGnBu")
# plt.title("AssA Scores Heatmap")
plt.xlabel("Block Size")
plt.ylabel("Window Size")
# plt.show()
plt.savefig("AssA_heatmap_normal_iou_dance.png", dpi = 1000,  bbox_inches='tight', pad_inches=0 )

# %% [markdown]
# ## Heatmap between buffer sizes for height modulated IOU SportsMOT

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define b1 and b2 values
b1_values = [0.25, 0.30, 0.35, 0.40]
b2_values = [0.25, 0.30, 0.35, 0.40, 0.45]

# HOTA scores
hota_scores = [
    [83.869, 83.885, 83.769, 83.769, 83.775 ],  # b1 = 0.25
    [83.937, 83.892, 83.787, 83.780, 83.784 ],  # b1 = 0.30
    [83.937, 83.937, 83.839, 83.837, 83.836],  # b1 = 0.35
    [83.974, 83.974, 83.865, 83.866, 83.868]  # b1 = 0.40
    # [83.421, None,   None,   None,   None,  83.421]  # b1 = 0.0
]

# AssA scores
assa_scores = [
    [74.741, 74.770, 74.582, 74.582, 74.584],  # b1 = 0.25
    [74.862, 74.783, 74.614, 74.601, 74.610],  # b1 = 0.30
    [74.863, 74.863, 74.708, 74.703, 74.692],  # b1 = 0.35
    [74.928, 74.928, 74.753, 74.755, 74.758]  # b1 = 0.40
    # [73.964, None,   None,   None,   None,  73.964]  # b1 = 0.0
]

# IDF1 scores
idf1_scores = [
    [83.531, 83.562, 83.454, 83.457, 83.451],  # b1 = 0.25
    [83.622, 83.550, 83.470, 83.462, 83.462],  # b1 = 0.30
    [83.621, 83.627, 83.534, 83.527, 83.519],  # b1 = 0.35
    [83.676, 83.677, 83.571, 83.573, 83.575]  # b1 = 0.40
    # [83.024, None,   None,   None,   None,  83.024]  # b1 = 0.0
]

# Function to create heatmaps
def create_heatmap(data, title, x_labels, y_labels, name , cmap="coolwarm"):
    plt.figure(figsize=(8, 6))
    sns.heatmap(data, annot=True, fmt=".3f", xticklabels=x_labels,annot_kws={"fontsize": 15}, yticklabels=y_labels, cmap=cmap, mask=np.isnan(data))
    # plt.title(title)
    plt.xlabel("b2")
    plt.ylabel("b1")
    # plt.show()
    plt.savefig("{}_heatmap_buffer_height_modulated_iou_sports.png".format(name), dpi = 1000,  bbox_inches='tight', pad_inches=0)
# Generate heatmaps
create_heatmap(np.array(hota_scores, dtype=np.float64), "HOTA Scores Heatmap (b1 vs b2)", b2_values, b1_values, "HOTA")
create_heatmap(np.array(assa_scores, dtype=np.float64), "AssA Scores Heatmap (b1 vs b2)", b2_values, b1_values, "AssA")
create_heatmap(np.array(idf1_scores, dtype=np.float64), "IDF1 Scores Heatmap (b1 vs b2)", b2_values, b1_values, "IDF1")

# %% [markdown]
# ## PLOT FOR BUFFER SIZES FOR  HEIGHT MODULATED EXTENDED IOU FOR DANCETRACK

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Define b1, b2, and metrics as separate lists
b1_values = [0.25, 0.30, 0.35, 0.40]
b2_values = [0.25, 0.30, 0.35, 0.40, 0.45]

# Metrics
hota = [
    [58.859, 58.616, 58.548, 58.659, 58.258],
    [58.949, 58.239, 58.444, 58.575, 58.388],
    [58.485, 58.606, 58.404, 58.355, 59.148],
    [59.299, 58.706, 58.882, 59.075, 58.895]
]

idf1 = [
    [61.287, 60.916, 60.956, 61.135, 60.923],
    [61.312, 60.358, 61.008, 61.182, 60.930],
    [60.932, 61.073, 60.935, 60.966, 61.947],
    [62.226, 61.364, 61.668, 62.047, 61.799]
]

assA = [
    [43.837, 43.498, 43.440, 43.579, 43.349],
    [43.880, 42.923, 43.276, 43.434, 43.186],
    [43.286, 43.407, 43.124, 43.109, 44.332],
    [44.465, 43.668, 43.970, 44.248, 44.131]
]

# Function to plot heatmap
def plot_heatmap(data, metric, title):
    plt.figure(figsize=(8, 6))
    sns.heatmap(data, annot=True, fmt=".3f", xticklabels=b2_values, yticklabels=b1_values, annot_kws={"fontsize": 15}, cmap="coolwarm", cbar_kws={"label": metric})
    # plt.title(f"{title} Heatmap")
    plt.xlabel("b2")
    plt.ylabel("b1")
    # plt.show()
    plt.savefig("{}_heatmap_buffer_height_modulated_iou_dance.png".format(title), dpi = 100, bbox_inches='tight', pad_inches=0)

# Plot heatmaps
plot_heatmap(np.array(hota, dtype = np.float64), "HOTA", "HOTA")
plot_heatmap(np.array(idf1, dtype = np.float64), "IDF1", "IDF1")
plot_heatmap(np.array(assA, dtype = np.float64), "AssA", "AssA")

# %% [markdown]
# ### Plot of final results in both the sequences for metrics

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Data for plotting
sequence_names = [
    "dancetrack0004", "dancetrack0005", "dancetrack0007", "dancetrack0010",
    "dancetrack0014", "dancetrack0018", "dancetrack0019", "dancetrack0025",
    "dancetrack0026", "dancetrack0030", "dancetrack0034", "dancetrack0035",
    "dancetrack0041", "dancetrack0043", "dancetrack0047", "dancetrack0058",
    "dancetrack0063", "dancetrack0065", "dancetrack0073", "dancetrack0077",
    "dancetrack0079", "dancetrack0081", "dancetrack0090", "dancetrack0094",
    "dancetrack0097", "COMBINED"
]

hota = [
    56.686, 65.056, 55.333, 78.773, 54.382, 86.343, 39.318, 70.607,
    46.272, 90.041, 52.122, 44.411, 35.04, 53.851, 63.543, 74.191,
    36.052, 67.943, 50.303, 69.749, 79.85, 52.38, 49.633, 57.384,
    70.969, 59.299
]
idf1 = [
    84.386, 83.203, 88.342, 92.292, 82.589, 79.597, 83.585, 78.847,
    74.61, 91.243, 80.478, 81.497, 65.219, 62.957, 74.794, 93.418,
    57.029, 86.3, 65.812, 88.767, 83.603, 75.99, 78.886, 74.452,
    93.015, 79.2
]
assa = [
    38.121, 50.87, 34.666, 67.248, 35.897, 93.668, 18.523, 63.409,
    28.915, 88.859, 33.82, 24.25, 19.065, 46.57, 54.032, 58.922,
    22.833, 53.498, 38.549, 54.831, 76.311, 36.173, 31.355, 44.581,
    54.153, 44.565
]
deta = [
    84.386, 83.203, 88.342, 92.292, 82.589, 79.597, 83.585, 78.847,
    74.61, 91.243, 80.478, 81.497, 65.219, 62.957, 74.794, 93.418,
    57.029, 86.3, 65.812, 88.767, 83.603, 75.99, 78.886, 74.452,
    93.015, 79.2
]
mota = [
    94.113, 96.012, 96.431, 96.244, 93.971, 84.395, 94.45, 88.996,
    81.067, 90.041, 93.971, 81.497, 93.45, 62.957, 74.794, 93.418,
    57.029, 86.3, 65.812, 88.767, 83.603, 75.99, 78.886, 74.452,
    93.015, 79.2
]

# # Plotting
# plt.figure(figsize=(15, 7))
# plt.plot(sequence_names, hota, label="HOTA", marker='o')
# plt.plot(sequence_names, idf1, label="IDF1", marker='s')
# plt.plot(sequence_names, assa, label="AssA", marker='^')
# plt.plot(sequence_names, deta, label="DetA", marker='x')
# plt.plot(sequence_names, mota, label="MOTA", marker='d')

# plt.title("Metrics by Sequence", fontsize=14)
# plt.xlabel("Sequence Names", fontsize=12)
# plt.ylabel("Metric Values", fontsize=12)
# plt.xticks(rotation=90, fontsize=10)
# plt.legend(fontsize=10)
# plt.grid(alpha=0.20)
# plt.tight_layout()

# plt.show()


# Set a modern and aesthetically pleasing style
sns.set_theme(style="whitegrid")

# Vibrant color palette for lines
palette = sns.color_palette("Set2")

# Plotting
plt.figure(figsize=(18, 9))
plt.plot(sequence_names, hota, label="HOTA", marker='o', color=palette[0], linewidth=2.5, markersize=8)
plt.plot(sequence_names, idf1, label="IDF1", marker='s', color=palette[1], linewidth=2.5, markersize=8)
plt.plot(sequence_names, assa, label="AssA", marker='^', color=palette[2], linewidth=2.5, markersize=8)
plt.plot(sequence_names, deta, label="DetA", marker='x', color=palette[3], linewidth=2.5, markersize=8)
plt.plot(sequence_names, mota, label="MOTA", marker='d', color=palette[4], linewidth=2.5, markersize=8)

# Titles and labels
plt.title("Metrics by Sequence", fontsize=18, fontweight='bold', color='black')
plt.xlabel("Sequence Names", fontsize=14, labelpad=10, fontweight='bold', color='black')
plt.ylabel("Metric Values", fontsize=14, labelpad=5, fontweight='bold', color='black')

# Customize ticks
plt.xticks(rotation=90, fontsize=12, color='black')
plt.yticks(fontsize=12, color='black')

# Add a legend
plt.legend(fontsize=12, frameon=True, fancybox=True, shadow=True, loc="upper right")

# Add a grid with a subtle touch
plt.grid(color='gray', linestyle='--', linewidth=1.5, alpha=0.0)

# Ensure tight layout
plt.tight_layout()
plt.savefig("dancetrack_results_line_plot.png", dpi = 1000, bbox_inches='tight', pad_inches=0)

# Show the plot
plt.show()

# %%
import pandas as pd

# Load the CSV file into a DataFrame
df = pd.read_csv('combined_output_data.csv')

# Display the first few rows of the dataframe to understand its structure
print(df.head(50))


# Extract only the 'HOTA' and 'IDF1' metrics
# Ensure that the columns are named exactly as 'HOTA' and 'IDF1'
# If these columns have slightly different names, adjust accordingly.
df_filtered = df[['Sequence']+ ['HOTA', 'AssA', 'DetA', 'MOTA', 'IDF1_x']]

# Show the filtered DataFrame with only the required columns
print(df_filtered)

HOTA = df_filtered['HOTA'] * 100
DetA = df_filtered['DetA'] * 100
MOTA = df_filtered['MOTA'] * 100
IDF1 = df_filtered['IDF1_x'] * 100
AssA = df_filtered['AssA'] * 100
sequence_names = df_filtered['Sequence']


# Set a modern and aesthetically pleasing style
sns.set_theme(style="whitegrid")

# Vibrant color palette for lines
palette = sns.color_palette("Set2")

# Plotting
plt.figure(figsize=(18, 9))
plt.plot(sequence_names, HOTA, label="HOTA", marker='o', color=palette[0], linewidth=2.5, markersize=8)
plt.plot(sequence_names, IDF1, label="IDF1", marker='s', color=palette[1], linewidth=2.5, markersize=8)
plt.plot(sequence_names, AssA, label="AssA", marker='^', color=palette[2], linewidth=2.5, markersize=8)
plt.plot(sequence_names, DetA, label="DetA", marker='x', color=palette[3], linewidth=2.5, markersize=8)
plt.plot(sequence_names, MOTA, label="MOTA", marker='d', color=palette[4], linewidth=2.5, markersize=8)

# Titles and labels
plt.title("Metrics by Sequence", fontsize=18, fontweight='bold', color='black')
plt.xlabel("Sequence Names", fontsize=14, labelpad=10, fontweight='bold', color='black')
plt.ylabel("Metric Values", fontsize=14, labelpad=10, fontweight='bold', color='black')

# Customize ticks
plt.xticks(rotation=90, fontsize=12, color='black')
plt.yticks(fontsize=12, color='black')

# Add a legend
plt.legend(fontsize=12, frameon=True, fancybox=True, shadow=True, loc="upper right")

# Add a grid with a subtle touch
plt.grid(color='gray', linestyle='--', linewidth=1.5, alpha=0.0)

# Ensure tight layout
plt.tight_layout()
plt.savefig("sports_results_line_plot.png", dpi = 1000, bbox_inches='tight', pad_inches=0)

# Show the plot
# plt.show()
# Out:
#               Sequence      HOTA      DetA      AssA      MOTA    IDF1_x  \
# 0         COMBINED_SEQ  0.839741  0.941374  0.749282  0.986836  0.836767
# 1   v_00HRwkvvjtQ_c001  0.799700  0.957771  0.667736  0.993526  0.794703
# 2   v_00HRwkvvjtQ_c003  0.884371  0.969212  0.806969  0.997943  0.891839
# 3   v_00HRwkvvjtQ_c005  0.865977  0.945938  0.792802  0.986953  0.866280
# 4   v_00HRwkvvjtQ_c007  0.806903  0.918221  0.709135  0.984360  0.853223
# 5   v_00HRwkvvjtQ_c008  0.933978  0.948738  0.919483  0.995282  0.978741
# 6   v_00HRwkvvjtQ_c011  0.779144  0.937575  0.647626  0.989543  0.753039
# 7   v_0kUtTtmLaJA_c004  0.866321  0.926102  0.810676  0.986433  0.905636
# 8   v_0kUtTtmLaJA_c005  0.915181  0.938817  0.892204  0.990982  0.964983
# 9   v_0kUtTtmLaJA_c006  0.879884  0.938275  0.825168  0.990283  0.898958
# 10  v_0kUtTtmLaJA_c007  0.932516  0.943424  0.921945  0.992016  0.977696
# 11  v_0kUtTtmLaJA_c008  0.954077  0.950059  0.958302  0.998339  0.999169
# ...
